# %%
import nibabel as nb
import numpy as np

wk_dir1 = '/Users/incehusain/fs_projects/test_new_freesurfer_version/'
wk_dir2 = '/Users/incehusain/fs_projects_7.4.1/dseg_segmentations_Language7T/'

img1 = nb.load(f"{wk_dir1}/sub-01_thalamus_dseg_7.4.1.nii.gz").get_fdata()
img2 = nb.load(f"{wk_dir2}/sub-01_thalamus_dseg.nii.gz").get_fdata()

print("Equal:", np.array_equal(img1, img2))
print("Max diff:", np.max(np.abs(img1 - img2)))
# Out:
# Equal: False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/incehusain/Documents/GitHub/Pontine7T/notebooks/check_dseg_freesurfer.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/Users/incehusain/Documents/GitHub/Pontine7T/notebooks/check_dseg_freesurfer.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> img2 = nb.load(f"{wk_dir2}/sub-01_thalamus_dseg.nii.gz").get_fdata()
#      <a href='vscode-notebook-cell:/Users/incehusain/Documents/GitHub/Pontine7T/notebooks/check_dseg_freesurfer.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> print("Equal:", np.array_equal(img1, img2))
# ---> <a href='vscode-notebook-cell:/Users/incehusain/Documents/GitHub/Pontine7T/notebooks/check_dseg_freesurfer.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> print("Max diff:", np.max(np.abs(img1 - img2)))
#
# ValueError: operands could not be broadcast together with shapes (143,121,125) (145,121,125)
