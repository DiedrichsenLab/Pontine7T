# %%
import nibabel as nb
import numpy as np

wk_dir1 = '/Users/incehusain/fs_projects/Language/sub-02/mri'
wk_dir2 = '/Users/incehusain/fs_projects/Language/sub-02_copy_test_v8_seg/mri'

img1 = nb.load(f"{wk_dir1}/ThalamicNuclei.v13.T1.mgz").get_fdata()
img2 = nb.load(f"{wk_dir2}/ThalamicNuclei.v13.T1.mgz").get_fdata()

print("Equal:", np.array_equal(img1, img2))
#print("Max diff:", np.max(np.abs(img1 - img2)))
# Out:
# Equal: True
