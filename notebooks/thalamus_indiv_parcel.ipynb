# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
pwd = '/Volumes/diedrichsen_data$/data/Cerebellum/Pontine7T/atlases/thalamus/indiv_parcellations/MDTB-ses2/MDTB_ses2_DCBC'
df = pd.read_csv(f'{pwd}/results.tsv', sep='\t')

# %%
sb.lineplot(data=df[df.type=='data'], x='runs', y='dcbc')
sb.lineplot(data=df[df.type=='data and group'], x='runs', y='dcbc')
group_performance = df[df.type=='group'].dcbc.mean()
plt.axhline(group_performance, color='black', linestyle='--')

# %%
df
# Out:
#      Unnamed: 0            type  runs      dcbc  subject
# 0             0           group     0  0.022596        1
# 1             0            data     1  0.101461        1
# 2             0  data and group     1  0.017571        1
# 3             0            data     2  0.027303        1
# 4             0  data and group     2  0.024570        1
# ..          ...             ...   ...       ...      ...
# 142           0  data and group    22  0.014311        3
# 143           0            data    23  0.018840        3
# 144           0  data and group    23  0.014252        3
# 145           0            data    24  0.017755        3
# 146           0  data and group    24  0.014191        3
#
# [147 rows x 5 columns]
