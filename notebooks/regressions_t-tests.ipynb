# %%
import nibabel as nb 
import numpy as np
import pandas as pd  
from scipy.stats import linregress, f_oneway
import seaborn as sns
import matplotlib.pyplot as plt
from Functional_Fusion.dataset import decompose_pattern_into_group_indiv_noise
from scripts import decomposing_variances
from scripts import make_atlas
#from scripts import bold_normalization 
import Functional_Fusion.dataset as ds
import Functional_Fusion.atlas_map as am
from scipy.stats import ttest_1samp
from scipy.stats import t
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import pingouin as pg
import Functional_Fusion.dataset as ds
import Functional_Fusion.array_convert as ac
# Out:
# /var/folders/91/7fqn4cp541g41hf5rkxmsnhh0000gn/T/ipykernel_53372/2078528683.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
wk_dir = '/Volumes/diedrichsen_data$/data/Cerebellum/Pontine7T/RegionOfInterest_BOLDMNI/data/group' #2min52 sec to load

dentate = np.load(wk_dir + '/data_dentate.npy')  #shape (16,16,10,voxels) (subj x repetition x condition x voxels)
cereb_gray = np.load(wk_dir + '/data_cerebgray.npy')
redn = np.load(wk_dir + '/data_rednucleus.npy')   
thalamus = np.load(wk_dir + '/data_thalamus.npy')       
pontine = np.load(wk_dir + '/data_pontine.npy') 
olive = np.load(wk_dir + '/data_olive.npy')

# %%
wk_dir = '/Volumes/diedrichsen_data$/data/Cerebellum/Pontine7T/RegionOfInterest_BOLDMNI/data/group' #2min52 sec to load

dentate_mdtb_ses2 = np.load(wk_dir + '/MDTB_ses2_dentate.npy')  #shape (16,16,10,voxels) (subj x repetition x condition x voxels)
#dentate_lang = np.load(wk_dir + '/Lang_dentate.npy')  
cereb_gray_mdtb_ses2 = np.load(wk_dir + '/MDTB_ses2_cereb_gray.npy')
#cereb_gray_lang = np.load(wk_dir + '/Lang_cereb_gray.npy')

# %%
#ANOVA on mean activity across ROIs 

dentate_cond = np.mean(dentate_lang, axis=(1,3)) 
cereb_gray_cond = np.nan_to_num(cereb_gray_lang)
cereb_gray_cond = np.mean(cereb_gray_cond, axis=(1,3))
#redn_cond = np.mean(redn, axis=(1,3))
#thalamus_cond = np.mean(thalamus, axis=(1,3))
#pontine_cond = np.mean(pontine, axis=(1,3))
#olive_cond = np.mean(olive, axis=(1,3))

condition_names_pontine = ["Instr", "Vis_S", "F_Seq", "ToM", "N_back", "Sem_Pred", "Act_Obs", "Flex_Ext", "Rest", "Rom_mov"]
condition_names_lang = ["Rest", "Word_reading", "Verb_generation", "Act_Obs_Act", "Act_Obs", "Intact_passage", "Degraded_passage", 
                        "Tongue_movement", "Finger_Seq", "ToM", "Aud_Narr", "N_back", "Oddball", "Demand_Grid", "Rom_mov", "Spatial_Nav",
                        "Sentence_Reading", "Non-word_reading"]

# Store all ROIs in a dictionary
roi_dict = {
    "Dentate": dentate_cond,
    "Cerebellar Gray": cereb_gray_cond,
    #"Red Nucleus": redn_cond,
    #"Thalamus": thalamus_cond,
    #"Pontine": pontine_cond,
    #"Olive": olive_cond
}

# Loop through each ROI and perform one-way ANOVA
for roi_name, roi_data in roi_dict.items():
    F_value, p_value = f_oneway(*roi_data.T)  # Transpose for correct shape
    print(f"{roi_name}: F-value = {F_value:.4f}, p-value = {p_value:.50f}")

    if p_value < 0.05:

        # Convert data to long-format for Tukey's test
        conditions = np.tile(condition_names_lang, roi_data.shape[0])
        values = roi_data.flatten()  # Flatten data for statsmodels

        # Perform Tukey's HSD test
        tukey = pairwise_tukeyhsd(endog=values, groups=conditions, alpha=0.05)
        print(tukey)
# Out:
# Dentate: F-value = 2.1413, p-value = 0.00593227584995731881123415263346032588742673397064
#           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================================
#      group1           group2      meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------
#          Act_Obs      Act_Obs_Act   0.0166 0.9967 -0.0264  0.0596  False
#          Act_Obs         Aud_Narr  -0.0038    1.0 -0.0468  0.0392  False
#          Act_Obs Degraded_passage   0.0013    1.0 -0.0417  0.0443  False
#          Act_Obs      Demand_Grid   0.0266 0.7644 -0.0164  0.0696  False
#          Act_Obs       Finger_Seq   0.0316 0.4649 -0.0114  0.0746  False
#          Act_Obs   Intact_passage  -0.0001    1.0  -0.043  0.0429  False
#          Act_Obs           N_back    0.015 0.9991  -0.028   0.058  False
#          Act_Obs Non-word_reading  -0.0001    1.0 -0.0431  0.0428  False
#          Act_Obs          Oddball   0.0057    1.0 -0.0373  0.0487  False
#          Act_Obs             Rest  -0.0118    1.0 -0.0547  0.0312  False
#          Act_Obs          Rom_mov   0.0035    1.0 -0.0394  0.0465  False
#          Act_Obs Sentence_Reading   0.0019    1.0 -0.0411  0.0449  False
#          Act_Obs      Spatial_Nav  -0.0069    1.0 -0.0499  0.0361  False
#          Act_Obs              ToM   0.0245 0.8636 -0.0185  0.0675  False
#          Act_Obs  Tongue_movement   0.0022    1.0 -0.0408  0.0451  False
#          Act_Obs  Verb_generation  -0.0127 0.9999 -0.0557  0.0303  False
#          Act_Obs     Word_reading   0.0065    1.0 -0.0365  0.0495  False
#      Act_Obs_Act         Aud_Narr  -0.0204 0.9702 -0.0634  0.0226  False
#      Act_Obs_Act Degraded_passage  -0.0153 0.9988 -0.0583  0.0277  False
#      Act_Obs_Act      Demand_Grid     0.01    1.0 -0.0329   0.053  False
#      Act_Obs_Act       Finger_Seq    0.015  0.999  -0.028   0.058  False
#      Act_Obs_Act   Intact_passage  -0.0166 0.9966 -0.0596  0.0263  False
#      Act_Obs_Act           N_back  -0.0016    1.0 -0.0446  0.0414  False
#      Act_Obs_Act Non-word_reading  -0.0167 0.9964 -0.0597  0.0263  False
#      Act_Obs_Act          Oddball  -0.0109    1.0 -0.0539  0.0321  False
#      Act_Obs_Act             Rest  -0.0284 0.6662 -0.0713  0.0146  False
#      Act_Obs_Act          Rom_mov   -0.013 0.9998  -0.056  0.0299  False
#      Act_Obs_Act Sentence_Reading  -0.0147 0.9993 -0.0576  0.0283  False
#      Act_Obs_Act      Spatial_Nav  -0.0235 0.8998 -0.0665  0.0195  False
#      Act_Obs_Act              ToM   0.0079    1.0 -0.0351  0.0509  False
#      Act_Obs_Act  Tongue_movement  -0.0144 0.9994 -0.0574  0.0286  False
#      Act_Obs_Act  Verb_generation  -0.0293 0.6083 -0.0723  0.0137  False
#      Act_Obs_Act     Word_reading  -0.0101    1.0 -0.0531  0.0329  False
#         Aud_Narr Degraded_passage   0.0051    1.0 -0.0379  0.0481  False
#         Aud_Narr      Demand_Grid   0.0305 0.5363 -0.0125  0.0734  False
#         Aud_Narr       Finger_Seq   0.0354 0.2576 -0.0075  0.0784  False
#         Aud_Narr   Intact_passage   0.0038    1.0 -0.0392  0.0468  False
#         Aud_Narr           N_back   0.0188 0.9869 -0.0242  0.0618  False
#         Aud_Narr Non-word_reading   0.0037    1.0 -0.0393  0.0467  False
#         Aud_Narr          Oddball   0.0095    1.0 -0.0334  0.0525  False
#         Aud_Narr             Rest  -0.0079    1.0 -0.0509   0.035  False
#         Aud_Narr          Rom_mov   0.0074    1.0 -0.0356  0.0504  False
#         Aud_Narr Sentence_Reading   0.0058    1.0 -0.0372  0.0487  False
#         Aud_Narr      Spatial_Nav  -0.0031    1.0 -0.0461  0.0399  False
#         Aud_Narr              ToM   0.0283 0.6675 -0.0146  0.0713  False
#         Aud_Narr  Tongue_movement    0.006    1.0  -0.037   0.049  False
#         Aud_Narr  Verb_generation  -0.0089    1.0 -0.0519  0.0341  False
#         Aud_Narr     Word_reading   0.0103    1.0 -0.0327  0.0533  False
# Degraded_passage      Demand_Grid   0.0253 0.8283 -0.0176  0.0683  False
# Degraded_passage       Finger_Seq   0.0303  0.545 -0.0127  0.0733  False
# Degraded_passage   Intact_passage  -0.0014    1.0 -0.0443  0.0416  False
# Degraded_passage           N_back   0.0137 0.9997 -0.0293  0.0567  False
# Degraded_passage Non-word_reading  -0.0014    1.0 -0.0444  0.0416  False
# Degraded_passage          Oddball   0.0044    1.0 -0.0386  0.0474  False
# Degraded_passage             Rest  -0.0131 0.9998  -0.056  0.0299  False
# Degraded_passage          Rom_mov   0.0022    1.0 -0.0407  0.0452  False
# Degraded_passage Sentence_Reading   0.0006    1.0 -0.0424  0.0436  False
# Degraded_passage      Spatial_Nav  -0.0082    1.0 -0.0512  0.0348  False
# Degraded_passage              ToM   0.0232 0.9093 -0.0198  0.0662  False
# Degraded_passage  Tongue_movement   0.0009    1.0 -0.0421  0.0438  False
# Degraded_passage  Verb_generation   -0.014 0.9996  -0.057   0.029  False
# Degraded_passage     Word_reading   0.0052    1.0 -0.0378  0.0482  False
#      Demand_Grid       Finger_Seq    0.005    1.0  -0.038   0.048  False
#      Demand_Grid   Intact_passage  -0.0267 0.7612 -0.0697  0.0163  False
#      Demand_Grid           N_back  -0.0117    1.0 -0.0546  0.0313  False
#      Demand_Grid Non-word_reading  -0.0268 0.7573 -0.0697  0.0162  False
#      Demand_Grid          Oddball  -0.0209 0.9627 -0.0639  0.0221  False
#      Demand_Grid             Rest  -0.0384 0.1455 -0.0814  0.0046  False
#      Demand_Grid          Rom_mov  -0.0231 0.9131 -0.0661  0.0199  False
#      Demand_Grid Sentence_Reading  -0.0247 0.8556 -0.0677  0.0183  False
#      Demand_Grid      Spatial_Nav  -0.0335 0.3529 -0.0765  0.0094  False
#      Demand_Grid              ToM  -0.0021    1.0 -0.0451  0.0409  False
#      Demand_Grid  Tongue_movement  -0.0245  0.865 -0.0674  0.0185  False
#      Demand_Grid  Verb_generation  -0.0393 0.1187 -0.0823  0.0036  False
#      Demand_Grid     Word_reading  -0.0201  0.974 -0.0631  0.0229  False
#       Finger_Seq   Intact_passage  -0.0317 0.4612 -0.0747  0.0113  False
#       Finger_Seq           N_back  -0.0166 0.9966 -0.0596  0.0263  False
#       Finger_Seq Non-word_reading  -0.0317 0.4567 -0.0747  0.0112  False
#       Finger_Seq          Oddball  -0.0259 0.8013 -0.0689  0.0171  False
#       Finger_Seq             Rest  -0.0434 0.0452 -0.0864 -0.0004   True
#       Finger_Seq          Rom_mov  -0.0281 0.6832  -0.071  0.0149  False
#       Finger_Seq Sentence_Reading  -0.0297 0.5844 -0.0727  0.0133  False
#       Finger_Seq      Spatial_Nav  -0.0385 0.1414 -0.0815  0.0045  False
#       Finger_Seq              ToM  -0.0071    1.0 -0.0501  0.0359  False
#       Finger_Seq  Tongue_movement  -0.0295 0.5989 -0.0724  0.0135  False
#       Finger_Seq  Verb_generation  -0.0443 0.0352 -0.0873 -0.0013   True
#       Finger_Seq     Word_reading  -0.0251 0.8379 -0.0681  0.0179  False
#   Intact_passage           N_back    0.015  0.999 -0.0279   0.058  False
#   Intact_passage Non-word_reading  -0.0001    1.0 -0.0431  0.0429  False
#   Intact_passage          Oddball   0.0058    1.0 -0.0372  0.0488  False
#   Intact_passage             Rest  -0.0117    1.0 -0.0547  0.0313  False
#   Intact_passage          Rom_mov   0.0036    1.0 -0.0394  0.0466  False
#   Intact_passage Sentence_Reading    0.002    1.0  -0.041   0.045  False
#   Intact_passage      Spatial_Nav  -0.0069    1.0 -0.0498  0.0361  False
#   Intact_passage              ToM   0.0246 0.8612 -0.0184  0.0675  False
#   Intact_passage  Tongue_movement   0.0022    1.0 -0.0408  0.0452  False
#   Intact_passage  Verb_generation  -0.0127 0.9999 -0.0556  0.0303  False
#   Intact_passage     Word_reading   0.0066    1.0 -0.0364  0.0495  False
#           N_back Non-word_reading  -0.0151 0.9989 -0.0581  0.0279  False
#           N_back          Oddball  -0.0093    1.0 -0.0522  0.0337  False
#           N_back             Rest  -0.0267 0.7583 -0.0697  0.0162  False
#           N_back          Rom_mov  -0.0114    1.0 -0.0544  0.0315  False
#           N_back Sentence_Reading   -0.013 0.9998  -0.056  0.0299  False
#           N_back      Spatial_Nav  -0.0219  0.944 -0.0649  0.0211  False
#           N_back              ToM   0.0095    1.0 -0.0335  0.0525  False
#           N_back  Tongue_movement  -0.0128 0.9999 -0.0558  0.0302  False
#           N_back  Verb_generation  -0.0277 0.7055 -0.0707  0.0153  False
#           N_back     Word_reading  -0.0085    1.0 -0.0515  0.0345  False
# Non-word_reading          Oddball   0.0058    1.0 -0.0371  0.0488  False
# Non-word_reading             Rest  -0.0116    1.0 -0.0546  0.0313  False
# Non-word_reading          Rom_mov   0.0037    1.0 -0.0393  0.0467  False
# Non-word_reading Sentence_Reading   0.0021    1.0 -0.0409   0.045  False
# Non-word_reading      Spatial_Nav  -0.0068    1.0 -0.0498  0.0362  False
# Non-word_reading              ToM   0.0246 0.8582 -0.0183  0.0676  False
# Non-word_reading  Tongue_movement   0.0023    1.0 -0.0407  0.0453  False
# Non-word_reading  Verb_generation  -0.0126 0.9999 -0.0556  0.0304  False
# Non-word_reading     Word_reading   0.0066    1.0 -0.0364  0.0496  False
#          Oddball             Rest  -0.0175 0.9941 -0.0605  0.0255  False
#          Oddball          Rom_mov  -0.0022    1.0 -0.0451  0.0408  False
#          Oddball Sentence_Reading  -0.0038    1.0 -0.0468  0.0392  False
#          Oddball      Spatial_Nav  -0.0126 0.9999 -0.0556  0.0304  False
#          Oddball              ToM   0.0188  0.987 -0.0242  0.0618  False
#          Oddball  Tongue_movement  -0.0035    1.0 -0.0465  0.0394  False
#          Oddball  Verb_generation  -0.0184 0.9894 -0.0614  0.0246  False
#          Oddball     Word_reading   0.0008    1.0 -0.0422  0.0438  False
#             Rest          Rom_mov   0.0153 0.9988 -0.0277  0.0583  False
#             Rest Sentence_Reading   0.0137 0.9997 -0.0293  0.0567  False
#             Rest      Spatial_Nav   0.0048    1.0 -0.0381  0.0478  False
#             Rest              ToM   0.0363 0.2216 -0.0067  0.0792  False
#             Rest  Tongue_movement   0.0139 0.9996 -0.0291  0.0569  False
#             Rest  Verb_generation  -0.0009    1.0 -0.0439   0.042  False
#             Rest     Word_reading   0.0183 0.9904 -0.0247  0.0612  False
#          Rom_mov Sentence_Reading  -0.0016    1.0 -0.0446  0.0414  False
#          Rom_mov      Spatial_Nav  -0.0105    1.0 -0.0534  0.0325  False
#          Rom_mov              ToM    0.021  0.962  -0.022  0.0639  False
#          Rom_mov  Tongue_movement  -0.0014    1.0 -0.0444  0.0416  False
#          Rom_mov  Verb_generation  -0.0163 0.9974 -0.0592  0.0267  False
#          Rom_mov     Word_reading    0.003    1.0   -0.04  0.0459  False
# Sentence_Reading      Spatial_Nav  -0.0088    1.0 -0.0518  0.0341  False
# Sentence_Reading              ToM   0.0226 0.9274 -0.0204  0.0656  False
# Sentence_Reading  Tongue_movement   0.0002    1.0 -0.0427  0.0432  False
# Sentence_Reading  Verb_generation  -0.0146 0.9993 -0.0576  0.0283  False
# Sentence_Reading     Word_reading   0.0046    1.0 -0.0384  0.0476  False
#      Spatial_Nav              ToM   0.0314 0.4767 -0.0116  0.0744  False
#      Spatial_Nav  Tongue_movement   0.0091    1.0 -0.0339  0.0521  False
#      Spatial_Nav  Verb_generation  -0.0058    1.0 -0.0488  0.0372  False
#      Spatial_Nav     Word_reading   0.0134 0.9998 -0.0296  0.0564  False
#              ToM  Tongue_movement  -0.0223 0.9334 -0.0653  0.0206  False
#              ToM  Verb_generation  -0.0372 0.1848 -0.0802  0.0058  False
#              ToM     Word_reading   -0.018 0.9917  -0.061   0.025  False
#  Tongue_movement  Verb_generation  -0.0149 0.9991 -0.0579  0.0281  False
#  Tongue_movement     Word_reading   0.0043    1.0 -0.0386  0.0473  False
#  Verb_generation     Word_reading   0.0192 0.9837 -0.0238  0.0622  False
# ------------------------------------------------------------------------
# Cerebellar Gray: F-value = 1.7524, p-value = 0.03382266038639281796607249930275429505854845046997
#           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================================
#      group1           group2      meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------
#          Act_Obs      Act_Obs_Act  -0.0063    1.0 -0.1009 0.0883  False
#          Act_Obs         Aud_Narr  -0.0324 0.9992  -0.127 0.0623  False
#          Act_Obs Degraded_passage  -0.0133    1.0  -0.108 0.0813  False
#          Act_Obs      Demand_Grid   0.0276 0.9999  -0.067 0.1222  False
#          Act_Obs       Finger_Seq   0.0306 0.9996 -0.0641 0.1252  False
#          Act_Obs   Intact_passage  -0.0401 0.9906 -0.1348 0.0545  False
#          Act_Obs           N_back   0.0026    1.0  -0.092 0.0972  False
#          Act_Obs Non-word_reading   -0.036 0.9973 -0.1306 0.0587  False
#          Act_Obs          Oddball  -0.0331  0.999 -0.1278 0.0615  False
#          Act_Obs             Rest  -0.0506 0.9162 -0.1452 0.0441  False
#          Act_Obs          Rom_mov  -0.0166    1.0 -0.1113  0.078  False
#          Act_Obs Sentence_Reading  -0.0275 0.9999 -0.1221 0.0672  False
#          Act_Obs      Spatial_Nav  -0.0341 0.9986 -0.1287 0.0605  False
#          Act_Obs              ToM  -0.0007    1.0 -0.0953  0.094  False
#          Act_Obs  Tongue_movement  -0.0463 0.9608 -0.1409 0.0483  False
#          Act_Obs  Verb_generation  -0.0593 0.7485 -0.1539 0.0354  False
#          Act_Obs     Word_reading  -0.0201    1.0 -0.1148 0.0745  False
#      Act_Obs_Act         Aud_Narr  -0.0261    1.0 -0.1207 0.0686  False
#      Act_Obs_Act Degraded_passage   -0.007    1.0 -0.1017 0.0876  False
#      Act_Obs_Act      Demand_Grid   0.0339 0.9987 -0.0607 0.1285  False
#      Act_Obs_Act       Finger_Seq   0.0369 0.9963 -0.0578 0.1315  False
#      Act_Obs_Act   Intact_passage  -0.0338 0.9987 -0.1285 0.0608  False
#      Act_Obs_Act           N_back   0.0089    1.0 -0.0857 0.1035  False
#      Act_Obs_Act Non-word_reading  -0.0297 0.9998 -0.1243  0.065  False
#      Act_Obs_Act          Oddball  -0.0268 0.9999 -0.1215 0.0678  False
#      Act_Obs_Act             Rest  -0.0443 0.9742 -0.1389 0.0503  False
#      Act_Obs_Act          Rom_mov  -0.0103    1.0  -0.105 0.0843  False
#      Act_Obs_Act Sentence_Reading  -0.0212    1.0 -0.1158 0.0735  False
#      Act_Obs_Act      Spatial_Nav  -0.0278 0.9999 -0.1224 0.0668  False
#      Act_Obs_Act              ToM   0.0056    1.0  -0.089 0.1003  False
#      Act_Obs_Act  Tongue_movement    -0.04 0.9909 -0.1346 0.0546  False
#      Act_Obs_Act  Verb_generation   -0.053 0.8804 -0.1476 0.0417  False
#      Act_Obs_Act     Word_reading  -0.0138    1.0 -0.1085 0.0808  False
#         Aud_Narr Degraded_passage   0.0191    1.0 -0.0756 0.1137  False
#         Aud_Narr      Demand_Grid     0.06 0.7312 -0.0347 0.1546  False
#         Aud_Narr       Finger_Seq    0.063 0.6517 -0.0317 0.1576  False
#         Aud_Narr   Intact_passage  -0.0078    1.0 -0.1024 0.0869  False
#         Aud_Narr           N_back    0.035  0.998 -0.0597 0.1296  False
#         Aud_Narr Non-word_reading  -0.0036    1.0 -0.0982  0.091  False
#         Aud_Narr          Oddball  -0.0008    1.0 -0.0954 0.0939  False
#         Aud_Narr             Rest  -0.0182    1.0 -0.1129 0.0764  False
#         Aud_Narr          Rom_mov   0.0158    1.0 -0.0789 0.1104  False
#         Aud_Narr Sentence_Reading   0.0049    1.0 -0.0897 0.0995  False
#         Aud_Narr      Spatial_Nav  -0.0017    1.0 -0.0964 0.0929  False
#         Aud_Narr              ToM   0.0317 0.9994  -0.063 0.1263  False
#         Aud_Narr  Tongue_movement  -0.0139    1.0 -0.1086 0.0807  False
#         Aud_Narr  Verb_generation  -0.0269 0.9999 -0.1215 0.0677  False
#         Aud_Narr     Word_reading   0.0122    1.0 -0.0824 0.1069  False
# Degraded_passage      Demand_Grid   0.0409 0.9885 -0.0537 0.1355  False
# Degraded_passage       Finger_Seq   0.0439 0.9763 -0.0507 0.1385  False
# Degraded_passage   Intact_passage  -0.0268 0.9999 -0.1215 0.0678  False
# Degraded_passage           N_back   0.0159    1.0 -0.0787 0.1105  False
# Degraded_passage Non-word_reading  -0.0227    1.0 -0.1173  0.072  False
# Degraded_passage          Oddball  -0.0198    1.0 -0.1145 0.0748  False
# Degraded_passage             Rest  -0.0373 0.9959 -0.1319 0.0574  False
# Degraded_passage          Rom_mov  -0.0033    1.0  -0.098 0.0913  False
# Degraded_passage Sentence_Reading  -0.0142    1.0 -0.1088 0.0805  False
# Degraded_passage      Spatial_Nav  -0.0208    1.0 -0.1154 0.0738  False
# Degraded_passage              ToM   0.0126    1.0  -0.082 0.1073  False
# Degraded_passage  Tongue_movement   -0.033  0.999 -0.1276 0.0617  False
# Degraded_passage  Verb_generation   -0.046 0.9633 -0.1406 0.0487  False
# Degraded_passage     Word_reading  -0.0068    1.0 -0.1015 0.0878  False
#      Demand_Grid       Finger_Seq    0.003    1.0 -0.0917 0.0976  False
#      Demand_Grid   Intact_passage  -0.0677 0.5171 -0.1624 0.0269  False
#      Demand_Grid           N_back   -0.025    1.0 -0.1196 0.0696  False
#      Demand_Grid Non-word_reading  -0.0636  0.635 -0.1582 0.0311  False
#      Demand_Grid          Oddball  -0.0607 0.7114 -0.1554 0.0339  False
#      Demand_Grid             Rest  -0.0782 0.2545 -0.1728 0.0165  False
#      Demand_Grid          Rom_mov  -0.0442 0.9746 -0.1389 0.0504  False
#      Demand_Grid Sentence_Reading  -0.0551 0.8423 -0.1497 0.0396  False
#      Demand_Grid      Spatial_Nav  -0.0617  0.686 -0.1563 0.0329  False
#      Demand_Grid              ToM  -0.0283 0.9999 -0.1229 0.0664  False
#      Demand_Grid  Tongue_movement  -0.0739 0.3519 -0.1685 0.0207  False
#      Demand_Grid  Verb_generation  -0.0869 0.1157 -0.1815 0.0078  False
#      Demand_Grid     Word_reading  -0.0477 0.9485 -0.1424 0.0469  False
#       Finger_Seq   Intact_passage  -0.0707 0.4342 -0.1654 0.0239  False
#       Finger_Seq           N_back   -0.028 0.9999 -0.1226 0.0666  False
#       Finger_Seq Non-word_reading  -0.0666 0.5507 -0.1612 0.0281  False
#       Finger_Seq          Oddball  -0.0637 0.6305 -0.1584 0.0309  False
#       Finger_Seq             Rest  -0.0812 0.1979 -0.1758 0.0135  False
#       Finger_Seq          Rom_mov  -0.0472 0.9534 -0.1418 0.0474  False
#       Finger_Seq Sentence_Reading  -0.0581 0.7777 -0.1527 0.0366  False
#       Finger_Seq      Spatial_Nav  -0.0647 0.6035 -0.1593   0.03  False
#       Finger_Seq              ToM  -0.0313 0.9995 -0.1259 0.0634  False
#       Finger_Seq  Tongue_movement  -0.0769 0.2821 -0.1715 0.0178  False
#       Finger_Seq  Verb_generation  -0.0899  0.085 -0.1845 0.0048  False
#       Finger_Seq     Word_reading  -0.0507 0.9144 -0.1454 0.0439  False
#   Intact_passage           N_back   0.0427 0.9819 -0.0519 0.1374  False
#   Intact_passage Non-word_reading   0.0042    1.0 -0.0905 0.0988  False
#   Intact_passage          Oddball    0.007    1.0 -0.0876 0.1016  False
#   Intact_passage             Rest  -0.0104    1.0 -0.1051 0.0842  False
#   Intact_passage          Rom_mov   0.0235    1.0 -0.0711 0.1182  False
#   Intact_passage Sentence_Reading   0.0127    1.0  -0.082 0.1073  False
#   Intact_passage      Spatial_Nav    0.006    1.0 -0.0886 0.1007  False
#   Intact_passage              ToM   0.0395 0.9922 -0.0552 0.1341  False
#   Intact_passage  Tongue_movement  -0.0062    1.0 -0.1008 0.0885  False
#   Intact_passage  Verb_generation  -0.0191    1.0 -0.1138 0.0755  False
#   Intact_passage     Word_reading     0.02    1.0 -0.0746 0.1146  False
#           N_back Non-word_reading  -0.0386 0.9939 -0.1332 0.0561  False
#           N_back          Oddball  -0.0357 0.9975 -0.1304 0.0589  False
#           N_back             Rest  -0.0532 0.8771 -0.1478 0.0415  False
#           N_back          Rom_mov  -0.0192    1.0 -0.1139 0.0754  False
#           N_back Sentence_Reading  -0.0301 0.9997 -0.1247 0.0646  False
#           N_back      Spatial_Nav  -0.0367 0.9965 -0.1313 0.0579  False
#           N_back              ToM  -0.0033    1.0 -0.0979 0.0914  False
#           N_back  Tongue_movement  -0.0489 0.9368 -0.1435 0.0457  False
#           N_back  Verb_generation  -0.0619 0.6814 -0.1565 0.0328  False
#           N_back     Word_reading  -0.0227    1.0 -0.1174 0.0719  False
# Non-word_reading          Oddball   0.0028    1.0 -0.0918 0.0975  False
# Non-word_reading             Rest  -0.0146    1.0 -0.1093   0.08  False
# Non-word_reading          Rom_mov   0.0193    1.0 -0.0753  0.114  False
# Non-word_reading Sentence_Reading   0.0085    1.0 -0.0862 0.1031  False
# Non-word_reading      Spatial_Nav   0.0019    1.0 -0.0928 0.0965  False
# Non-word_reading              ToM   0.0353 0.9978 -0.0594 0.1299  False
# Non-word_reading  Tongue_movement  -0.0103    1.0  -0.105 0.0843  False
# Non-word_reading  Verb_generation  -0.0233    1.0  -0.118 0.0713  False
# Non-word_reading     Word_reading   0.0158    1.0 -0.0788 0.1105  False
#          Oddball             Rest  -0.0174    1.0 -0.1121 0.0772  False
#          Oddball          Rom_mov   0.0165    1.0 -0.0781 0.1112  False
#          Oddball Sentence_Reading   0.0057    1.0  -0.089 0.1003  False
#          Oddball      Spatial_Nav   -0.001    1.0 -0.0956 0.0937  False
#          Oddball              ToM   0.0325 0.9992 -0.0622 0.1271  False
#          Oddball  Tongue_movement  -0.0132    1.0 -0.1078 0.0815  False
#          Oddball  Verb_generation  -0.0261    1.0 -0.1208 0.0685  False
#          Oddball     Word_reading    0.013    1.0 -0.0816 0.1076  False
#             Rest          Rom_mov    0.034 0.9986 -0.0607 0.1286  False
#             Rest Sentence_Reading   0.0231    1.0 -0.0715 0.1177  False
#             Rest      Spatial_Nav   0.0165    1.0 -0.0782 0.1111  False
#             Rest              ToM   0.0499 0.9251 -0.0447 0.1445  False
#             Rest  Tongue_movement   0.0043    1.0 -0.0904 0.0989  False
#             Rest  Verb_generation  -0.0087    1.0 -0.1033 0.0859  False
#             Rest     Word_reading   0.0304 0.9997 -0.0642 0.1251  False
#          Rom_mov Sentence_Reading  -0.0109    1.0 -0.1055 0.0838  False
#          Rom_mov      Spatial_Nav  -0.0175    1.0 -0.1121 0.0772  False
#          Rom_mov              ToM   0.0159    1.0 -0.0787 0.1106  False
#          Rom_mov  Tongue_movement  -0.0297 0.9998 -0.1243  0.065  False
#          Rom_mov  Verb_generation  -0.0427 0.9822 -0.1373  0.052  False
#          Rom_mov     Word_reading  -0.0035    1.0 -0.0982 0.0911  False
# Sentence_Reading      Spatial_Nav  -0.0066    1.0 -0.1013  0.088  False
# Sentence_Reading              ToM   0.0268 0.9999 -0.0678 0.1214  False
# Sentence_Reading  Tongue_movement  -0.0188    1.0 -0.1135 0.0758  False
# Sentence_Reading  Verb_generation  -0.0318 0.9994 -0.1264 0.0628  False
# Sentence_Reading     Word_reading   0.0073    1.0 -0.0873  0.102  False
#      Spatial_Nav              ToM   0.0334 0.9989 -0.0612 0.1281  False
#      Spatial_Nav  Tongue_movement  -0.0122    1.0 -0.1068 0.0824  False
#      Spatial_Nav  Verb_generation  -0.0252    1.0 -0.1198 0.0695  False
#      Spatial_Nav     Word_reading    0.014    1.0 -0.0807 0.1086  False
#              ToM  Tongue_movement  -0.0456 0.9659 -0.1403  0.049  False
#              ToM  Verb_generation  -0.0586 0.7653 -0.1532  0.036  False
#              ToM     Word_reading  -0.0195    1.0 -0.1141 0.0752  False
#  Tongue_movement  Verb_generation   -0.013    1.0 -0.1076 0.0817  False
#  Tongue_movement     Word_reading   0.0262    1.0 -0.0685 0.1208  False
#  Verb_generation     Word_reading   0.0391 0.9928 -0.0555 0.1338  False
# -----------------------------------------------------------------------

# %%
#group-level regression (creating .tsv files)

cereb_gray_mdtb_ses2 = np.nan_to_num(cereb_gray_mdtb_ses2)

y = np.mean(dentate_mdtb_ses2, axis=(0,1,3)) #shape (10,) #avg activity per condition across subjects, runs, and voxels 

x = np.mean(cereb_gray_mdtb_ses2, axis=(0,1,3))  

#condition_names_pontine = ["Instr", "Vis_S", "F_Seq", "ToM", "N_back", "Sem_Pred", "Act_Obs", "Flex_Ext", "Rest", "Rom_mov"]
#condition_labels_language = ["Rest", "Word_reading", "Verb_generation", "Act_Obs_Act", "Act_Obs", "Intact_passage", "Degraded_passage", 
 #                       "Tongue_movement", "Finger_Seq", "ToM", "Aud_Narr", "N_back", "Oddball", "Demand_Grid", "Rom_mov", "Spatial_Nav",
  #                      "Sentence_Reading", "Non-word_reading"]

#condition_labels_mdtb_ses1 = ["NoGo","Go", "ToM", "VideoAct","VideoKnots", "Unpleas_Scenes", "Pleas_scenes", "Math", "Digit_Judg"
        #            ,"CheckerBoard", "Sad_Faces", "Happy_Faces", "Interval_Timing", "Motor_Imagery", "Finger_Simple", "Finger_Seq"
          #          ,"Verbal0Back", "Verbal2Back","Object0Back", "Object2Back", "Spatial_Nav", "StroopIncon", "StroopCon", "Verb_generation",
     #               "Word_reading", "Vis_S_Small", "Vis_S_Med", "Vis_S_Large", "Rest"]

condition_labels_mdtb_ses2 = ["CPRO", "Prediction", "PredictViol", "PredictScram", "VerbGen", "WordRead", "SpatialNav", "SpatialMap_Easy",
                              "SpatialMap_Med", "SpatialMap_Diff", "NatureMovie", "RomanceMovie", "LandscapeMovie", "FingerSimple", "FingerSeq",
                              "MentalRotation_Easy", "MentalRotation_Med", "MentalRotation_Diff", "Object0Back", "Object2Back", 
                              "BodyMotionIntact", "BodyMotionScram", "RespAltEasy", "RespAltMed", "RespAltDiff", "VisualSearchSmall", "VisualSearchMed",
                              "VisualSearchLarge","ToM", "VideoAct", "VideoKnots", "Rest"]

results = []

# Linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)
regression_line = f"{slope:.4f} * x + {intercept:.4f}"  # Store as a string
F_value = (r_value**2 / (1 - r_value**2)) * ((len(condition_labels_mdtb_ses2) - 2) / 1)

for i in range(len(condition_labels_mdtb_ses2)):
    results.append(["group", "dentate vs cereb_gray", condition_labels_mdtb_ses2[i], x[i], y[i], regression_line, r_value**2, F_value, p_value, "MDTB_ses2"])

# Convert to a DataFrame
df = pd.DataFrame(results, columns=["Subjects", "ROIs", "cond", "x", "y", "regression line", "R2", "F-value", "p-value", "dataset"])

# Save to TSV
df.to_csv("group_ROI_correlations.tsv", sep="\t", mode = 'a', index=False)

# %%
# group plots

df = pd.read_csv('group_ROI_correlations.tsv', sep="\t")

df = df[df["dataset"] == "MDTB_ses2"]

# List of ROI pairs to loop over
roi_pairs = [
    "cereb_gray vs dentate",
    "dentate vs cereb_gray",
    #"cereb_gray vs pontine",
    #"cereb_gray vs olive",
    #"dentate vs pontine",
    #"thalamus vs dentate",
    #"redn vs dentate",
    #"olive vs redn",
    #"dentate vs olive",
]

# Loop over each ROI pair
for roi in roi_pairs:
    roi_data = df[df['ROIs'] == roi]

    # Extract the data for plotting
    x = roi_data['x']
    y = roi_data['y']
    condition_labels = roi_data['cond']

    # Regression line parsing
    regression_line = roi_data['regression line'].iloc[0]
    slope, intercept = map(float, regression_line.split(" * x + "))

    # Create a scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color="blue")

    # Plot regression line
    plt.plot(x, slope * x + intercept, color="red")

    # Add labels and title
    plt.xlabel(f"{roi.split(' vs ')[1]} activity (Pontine)")
    plt.ylabel(f"{roi.split(' vs ')[0]} activity (Pontine)")
    plt.title(f"{roi}")

    # Extract statistical values
    r_squared = float(roi_data['R2'].iloc[0])
    p_value = float(roi_data['p-value'].iloc[0])

    # Display R² and p-value on the plot
    plt.text(0.05, 0.95, f"R² = {r_squared:.4f}", transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color='black')
    plt.text(0.05, 0.90, f"p = {p_value:.4f}", transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color='black')

    # Add condition labels to points
    for i, label in enumerate(condition_labels):
        plt.text(x.iloc[i], y.iloc[i], label, fontsize=9, color='black', ha='right', va='bottom')

    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
#group: list R^2 values and p-value per roi

df = pd.read_csv('group_ROI_correlations.tsv', sep="\t")

# Iterate over each subject and selected ROI combination
for roi in df['ROIs'].unique():  # Iterate over each unique roi

    roi_data = df[df['ROIs'] == roi]  # Filter data for the current ROI
   
    r_squared = roi_data['R2'].iloc[0]  
    p_value = roi_data['p-value'].iloc[0]
        
        # Print the R² value for the subject-ROI pair
    print(f"group {roi}: R² = {r_squared:.4f}, p = {p_value:.4f}")
# Out:
# group dentate vs cereb_gray: R² = 0.8231, p = 0.0003
# group cereb_gray vs pontine: R² = 0.1861, p = 0.2132
# group cereb_gray vs olive: R² = 0.6128, p = 0.0074
# group thalamus vs dentate: R² = 0.6331, p = 0.0059
# group dentate vs pontine: R² = 0.2153, p = 0.1767
# group redn vs dentate: R² = 0.7952, p = 0.0005
# group olive vs redn: R² = 0.7291, p = 0.0017
# group dentate vs olive: R² = 0.7632, p = 0.0010

# %%
#subject-wise regression (creating .tsv files)

#dentate vs cereb_gray
#cereb_gray vs pontine
#cereb_gray vs olive
#dentate vs pontine
#thalamus vs dentate
#redn vs dentate
#olive vs redn
#dentate vs olive

#pt_base ='/Volumes/diedrichsen_data$/data/Cerebellum/Pontine7T'

pt_base = '/Volumes/diedrichsen_data$/data/FunctionalFusion/MDTB'

T = pd.read_csv(f'{pt_base}/participants.tsv', sep='\t')
subj = list(T["participant_id"])

#T = pd.read_csv(f'{pt_base}/participants.tsv', sep='\t')
#subj = [i for i, good_value in zip(T.participant_id, T.good) if good_value == 1]

cereb_gray = np.nan_to_num(cereb_gray_mdtb_ses2)

subj_avg_cereb_gray = np.mean(cereb_gray_mdtb_ses2, axis=(1,3))  # shape (16,10) (subjects x conditions)
subj_avg_dentate = np.mean(dentate_mdtb_ses2, axis=(1,3))  # shape  (16,10)

#condition_labels_pontine7T = ["Instr", "Vis_S", "F_Seq", "ToM", "N_back", "Sem_Pred", "Act_Obs", "Flex_Ext", "Rest", "Rom_mov"]
#condition_labels_lang = ["Rest", "Word_reading", "Verb_generation", "Act_Obs_Act", "Act_Obs", "Intact_passage", "Degraded_passage", 
 #                       "Tongue_movement", "Finger_Seq", "ToM", "Aud_Narr", "N_back", "Oddball", "Demand_Grid", "Rom_mov", "Spatial_Nav",
  #                      "Sentence_Reading", "Non-word_reading"]

#condition_labels_mdtb_ses1 = ["NoGo","Go", "ToM", "VideoAct","VideoKnots", "Unpleas_Scenes", "Pleas_scenes", "Math", "Digit_Judg"
 #                   ,"CheckerBoard", "Sad_Faces", "Happy_Faces", "Interval_Timing", "Motor_Imagery", "Finger_Simple", "Finger_Seq"
  #                  ,"Verbal0Back", "Verbal2Back","Object0Back", "Object2Back", "Spatial_Nav", "StroopIncon", "StroopCon", "Verb_generation",
   #                 "Word_reading", "Vis_S_Small", "Vis_S_Med", "Vis_S_Large", "Rest"]


condition_labels_mdtb_ses2 = ["CPRO", "Prediction", "PredictViol", "PredictScram", "VerbGen", "WordRead", "SpatialNav", "SpatialMap_Easy",
                              "SpatialMap_Med", "SpatialMap_Diff", "NatureMovie", "RomanceMovie", "LandscapeMovie", "FingerSimple", "FingerSeq",
                              "MentalRotation_Easy", "MentalRotation_Med", "MentalRotation_Diff", "Object0Back", "Object2Back", 
                              "BodyMotionIntact", "BodyMotionScram", "RespAltEasy", "RespAltMed", "RespAltDiff", "VisualSearchSmall", "VisualSearchMed",
                              "VisualSearchLarge","ToM", "VideoAct", "VideoKnots", "Rest"]

results = []

for subj_idx, subj_id in enumerate(subj):
    y = subj_avg_dentate[subj_idx, :]
    x = subj_avg_cereb_gray[subj_idx, :]

    # Linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    regression_line = f"{slope:.4f} * x + {intercept:.4f}"
    F_value = (r_value**2 / (1 - r_value**2)) * ((len(condition_labels) - 2) / 1)
    
    # t-value for slope significance
    t_value = slope / std_err  
    slope_p_value = 2 * t.sf(abs(t_value), df=len(condition_labels) - 2)  # Two-tailed test

    for i in range(len(condition_labels)):
        results.append([
            subj_id, 
            "dentate vs cereb_gray", 
            condition_labels_mdtb_ses2[i], 
            x[i], 
            y[i], 
            regression_line, 
            r_value**2, 
            F_value, 
            p_value,
            std_err,          # Standard Error of the slope
            t_value,          # t-value for slope significance
            slope_p_value,
            "MDTB_ses2"     # p-value for slope significance
        ])

# Convert to DataFrame
df = pd.DataFrame(results, columns=[
    "Subjects", "ROIs", "cond", "x", "y", 
    "regression line", "R2", "F-value", "p-value",
    "SE_slope", "t-value", "slope_p-value", "dataset"
])

# Save to TSV
df.to_csv("subjectwise_ROI_correlations.tsv", sep="\t", mode='a', index=False)

# %%
#t-test slopes

df = pd.read_csv('subjectwise_ROI_correlations.tsv', sep="\t")

df = df[df["dataset"] == "MDTB_ses2"]


# Define the list of ROI pairs you want to include
roi_pairs = [
    #"cereb_gray vs pontine",
    #"cereb_gray vs olive",
    #"dentate vs pontine",
    #"thalamus vs dentate",
    #"redn vs dentate",
    #"olive vs redn",
   # "dentate vs olive",
    "dentate vs cereb_gray",
    "cereb_gray vs dentate"
]

# Iterate over each ROI pair
for roi_pair in roi_pairs:
    # Filter the DataFrame to only include the selected ROI pair
    df_filtered = df[df['ROIs'] == roi_pair]
    
    # Create an empty list to store the slopes for each subject
    slopes = []

    # Iterate over each subject in the filtered DataFrame
    for subj_id in df_filtered['Subjects'].unique():  # Iterate over each unique subject
        subject_data = df_filtered[df_filtered['Subjects'] == subj_id]
        
        # Extract the regression line for the subject and ROI pair
        regression_line = subject_data['regression line'].iloc[0]  # Assuming one regression line per subject/ROI pair
        
        # Extract the slope from the regression line string
        slope_str = regression_line.split(' * x')[0]  # Get the part before ' * x'
        
        # Convert the slope part to a float
        try:
            slope = float(slope_str)
        except ValueError:
            slope = None  # In case the string can't be converted to a float
        
        # Append the extracted slope to the list
        if slope is not None:
            slopes.append(slope)

    slopes_array = np.array(slopes)

    # Perform one-sample t-test on the slopes
    t_stat, p_val = ttest_1samp(slopes_array, 0)

    # Print the result for the current ROI pair
    print(f"ROI Pair: {roi_pair}")
    print(f"T-statistic: {t_stat}")#
    print(f"P-value: {p_val}")
    print("-" * 40)
# Out:
# ROI Pair: dentate vs cereb_gray
# T-statistic: 15.342004522793742
# P-value: 1.4251748702500996e-13
# ----------------------------------------
# ROI Pair: cereb_gray vs dentate
# T-statistic: 15.862245615857196
# P-value: 7.053313085656864e-14
# ----------------------------------------

# %%
#subject plots

df = pd.read_csv('subjectwise_ROI_correlations.tsv', sep="\t")

subject_id = 'S98'  # Specify the subject
subject_data = df[df['Subjects'] == subject_id]

# Loop through each ROI (or filter if needed)
for roi in subject_data['ROIs'].unique():  # Loop through the unique ROIs
    roi_data = subject_data[subject_data['ROIs'] == roi]

    # Extract the data for plotting
    x = roi_data['x']
    y = roi_data['y']
    condition_labels = roi_data['cond']
    regression_line = roi_data['regression line'].iloc[0]  # Assuming the same regression line for each ROI

    # Create a scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color="blue")

    # Extract slope and intercept for the regression line
    slope, intercept = map(float, regression_line.split(" * x + "))  # This assumes your regression line is in the form "slope * x + intercept"
    plt.plot(x, slope * x + intercept, color="red")

    # Add labels and title
    plt.xlabel(f"{roi.split(' vs ')[1]} activity")
    plt.ylabel(f"{roi.split(' vs ')[0]} activity")
    plt.title(f"{subject_id}, {roi}")
    plt.legend()

    r_squared = float(roi_data['R2'].iloc[0])  # Extract the R² value from the dataframe for this ROI
    p_value = float(roi_data['p-value'].iloc[0])  # Extract the p-value from the dataframe for this ROI
    p_value_slope = float(roi_data['slope_p-value'].iloc[0])

    # Display R² and p-value on the plot
    plt.text(0.05, 0.95, f"R² = {r_squared:.4f}", transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color='black')
    plt.text(0.05, 0.90, f"p = {p_value:.4f}", transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color='black')
    plt.text(0.05, 0.85, f"p_slope = {p_value:.4f}", transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', color='black')


    # Optionally, add labels for conditions
    for i, label in enumerate(condition_labels):  # Use enumerate to iterate over condition labels
        plt.text(x.iloc[i], y.iloc[i], label, fontsize=9, color='black', ha='right', va='bottom')

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#List R^2 values and p-value per subject

# Load the .tsv file
df = pd.read_csv('subjectwise_ROI_correlations.tsv', sep="\t")

# Define the ROIs you want to include
selected_rois = ["dentate vs cereb_gray"]  # Replace with actual ROI names

# Filter the DataFrame to only include selected ROIs
df_filtered = df[df['ROIs'].isin(selected_rois)]

# Iterate over each subject and selected ROI combination
for subj_id in df_filtered['Subjects'].unique():  # Iterate over each unique subject
    subject_data = df_filtered[df_filtered['Subjects'] == subj_id]
    
    for roi in subject_data['ROIs'].unique():  # Iterate over each unique selected ROI
        roi_data = subject_data[subject_data['ROIs'] == roi]
        
        # Extract the R² value (assuming it's stored in the "R2" column)
        r_squared = roi_data['R2'].iloc[0]  # Assuming the R² value is the same for all conditions within a subject-ROI pair
        p_value = roi_data['p-value'].iloc[0]
        p_value_slope = roi_data['slope_p-value'].iloc[0]   
        
        # Print the R² value for the subject-ROI pair
        print(f"Subject {subj_id}, ROI {roi}: R² = {r_squared:.4f}, p = {p_value:.4f}, p_slope = {p_value_slope:.4f}")
# Out:
# Subject S98, ROI dentate vs cereb_gray: R² = 0.8807, p = 0.0001, p_slope = 0.0001
# Subject S97, ROI dentate vs cereb_gray: R² = 0.7890, p = 0.0006, p_slope = 0.0006
# Subject S96, ROI dentate vs cereb_gray: R² = 0.7409, p = 0.0014, p_slope = 0.0014
# Subject S95, ROI dentate vs cereb_gray: R² = 0.3772, p = 0.0589, p_slope = 0.0589
# Subject S01, ROI dentate vs cereb_gray: R² = 0.5847, p = 0.0100, p_slope = 0.0100
# Subject S03, ROI dentate vs cereb_gray: R² = 0.7212, p = 0.0019, p_slope = 0.0019
# Subject S04, ROI dentate vs cereb_gray: R² = 0.7009, p = 0.0025, p_slope = 0.0025
# Subject S07, ROI dentate vs cereb_gray: R² = 0.7040, p = 0.0024, p_slope = 0.0024
# Subject S08, ROI dentate vs cereb_gray: R² = 0.2900, p = 0.1083, p_slope = 0.1083
# Subject S10, ROI dentate vs cereb_gray: R² = 0.2445, p = 0.1463, p_slope = 0.1463
# Subject S11, ROI dentate vs cereb_gray: R² = 0.0003, p = 0.9596, p_slope = 0.9596
# Subject S12, ROI dentate vs cereb_gray: R² = 0.0675, p = 0.4685, p_slope = 0.4685
# Subject S13, ROI dentate vs cereb_gray: R² = 0.6321, p = 0.0060, p_slope = 0.0060
# Subject S14, ROI dentate vs cereb_gray: R² = 0.6393, p = 0.0055, p_slope = 0.0055
# Subject S16, ROI dentate vs cereb_gray: R² = 0.3986, p = 0.0503, p_slope = 0.0503
# Subject S17, ROI dentate vs cereb_gray: R² = 0.7001, p = 0.0025, p_slope = 0.0025

# %%
#cereb_gray vs pontine
#cereb_gray vs olive
#dentate vs pontine
#thalamus vs dentate
#redn vs dentate
#olive vs redn
#dentate vs olive
#dentate vs cereb_gray

# Compute ANOVA and t-tests
df = pd.read_csv('subjectwise_ROI_correlations.tsv', sep="\t")

selected_rois = ["dentate vs cereb_gray"]

# Filter the DataFrame for selected ROIs and R² > 0.50
df_filtered = df[(df['ROIs'].isin(selected_rois)) & (df['slope_p-value'] < 0.05)]


# Create an empty list to store residuals for each condition
residuals = []

# Loop through the unique conditions
for condition in df_filtered['cond'].unique():
    condition_data = df_filtered[df_filtered['cond'] == condition]
    
    condition_residuals = []
    
    # Loop through each subject to calculate residuals based on their own regression line
    for subj_id in condition_data['Subjects'].unique():
        subject_data = condition_data[condition_data['Subjects'] == subj_id]
        
        x = subject_data['x']
        y = subject_data['y']
        
        # Extract the regression line (slope, intercept)
        regression_line = subject_data['regression line'].iloc[0] 
        slope, intercept = map(float, regression_line.split(" * x + "))
        
        # Calculate predicted y-values based on the regression line
        predicted_y = slope * x + intercept
        
        # Calculate residuals (observed y - predicted y)
        residuals_for_subject = y - predicted_y
        
        # Append subject's residuals to the condition's list
        condition_residuals.append(residuals_for_subject)
    
    # After looping through subjects for this condition, add the residuals for this condition
    residuals.append(np.array(condition_residuals).T)  # Transpose to get subjects as rows

residuals = np.array(residuals).T  # shape is (subjects x 1 x conditions) (10,1,10)

residuals = residuals.squeeze()

residuals = residuals.T  # shape is (conditions x subjects) (10,10)

# Perform one-way ANOVA across conditions (i.e., residuals across all subjects for each condition)
F_value, p_value = f_oneway(*residuals)

print(f"{selected_rois}")
print(f"ANOVA F-value: {F_value:.4f}")
print(f"ANOVA p-value: {p_value:.4f}")

from statsmodels.stats.multicomp import pairwise_tukeyhsd
import pandas as pd

# Prepare data for Tukey’s HSD
residuals_flat = residuals.flatten()
conditions_repeated = np.repeat(df_filtered['cond'].unique(), residuals.shape[1])

# Perform Tukey’s HSD
tukey_results = pairwise_tukeyhsd(endog=residuals_flat,  # Data values
                                  groups=conditions_repeated,  # Condition labels
                                  alpha=0.05)  # Significance level

# Display results
print(tukey_results)


# Collect t-values and p-values
t_values = []
p_values = []

for i in range (10): #number of conditions
    t_stat, p_val = ttest_1samp(residuals[i, :], 0)
    t_values.append(t_stat)
    p_values.append(p_val)

# Apply FDR correction
reject, p_values_corrected, _, _ = multipletests(p_values, alpha=0.1, method='fdr_bh')

# Store flagged results
flagged_results = []

for i, cond in enumerate(df_filtered['cond'].unique()):
    t_stat, p_val, p_val_corrected = t_values[i], p_values[i], p_values_corrected[i]
    
    # Flag conditions with corrected p-value < 0.05
    flag = "Significant" if reject[i] else "Not Significant"
    
    flagged_results.append([cond, t_stat, p_val, p_val_corrected, flag])

# Convert flagged results to DataFrame
flagged_df = pd.DataFrame(flagged_results, 
                          columns=["Condition", "T-statistic", "P-value", "FDR P-value", "Significance (FDR)"])

# Display the flagged results
print(flagged_df)
# Out:
# ['dentate vs cereb_gray']
# ANOVA F-value: 3.1651
# ANOVA p-value: 0.0023
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#  Act_Obs    F_Seq   0.0099 0.0322  0.0005 0.0193   True
#  Act_Obs Flex_Ext    0.012  0.003  0.0026 0.0214   True
#  Act_Obs    Instr   0.0065 0.4426 -0.0029 0.0159  False
#  Act_Obs   N_back   0.0105 0.0172  0.0011 0.0199   True
#  Act_Obs     Rest   0.0069 0.3448 -0.0025 0.0164  False
#  Act_Obs  Rom_mov   0.0051 0.7556 -0.0043 0.0145  False
#  Act_Obs Sem_Pred   0.0089 0.0826 -0.0006 0.0183  False
#  Act_Obs      ToM   0.0088 0.0864 -0.0006 0.0182  False
#  Act_Obs    Vis_S   0.0121 0.0026  0.0027 0.0216   True
#    F_Seq Flex_Ext   0.0022 0.9991 -0.0073 0.0116  False
#    F_Seq    Instr  -0.0034 0.9755 -0.0128  0.006  False
#    F_Seq   N_back   0.0006    1.0 -0.0088   0.01  False
#    F_Seq     Rest  -0.0029 0.9909 -0.0124 0.0065  False
#    F_Seq  Rom_mov  -0.0048 0.8266 -0.0142 0.0047  False
#    F_Seq Sem_Pred   -0.001    1.0 -0.0104 0.0084  False
#    F_Seq      ToM  -0.0011    1.0 -0.0105 0.0084  False
#    F_Seq    Vis_S   0.0023 0.9987 -0.0072 0.0117  False
# Flex_Ext    Instr  -0.0055 0.6636  -0.015 0.0039  False
# Flex_Ext   N_back  -0.0015 0.9999  -0.011 0.0079  False
# Flex_Ext     Rest  -0.0051 0.7625 -0.0145 0.0043  False
# Flex_Ext  Rom_mov  -0.0069 0.3517 -0.0163 0.0025  False
# Flex_Ext Sem_Pred  -0.0032 0.9849 -0.0126 0.0063  False
# Flex_Ext      ToM  -0.0032 0.9831 -0.0126 0.0062  False
# Flex_Ext    Vis_S   0.0001    1.0 -0.0093 0.0095  False
#    Instr   N_back    0.004 0.9313 -0.0054 0.0134  False
#    Instr     Rest   0.0005    1.0  -0.009 0.0099  False
#    Instr  Rom_mov  -0.0014    1.0 -0.0108 0.0081  False
#    Instr Sem_Pred   0.0024 0.9981  -0.007 0.0118  False
#    Instr      ToM   0.0023 0.9984 -0.0071 0.0118  False
#    Instr    Vis_S   0.0057 0.6368 -0.0038 0.0151  False
#   N_back     Rest  -0.0035 0.9672  -0.013 0.0059  False
#   N_back  Rom_mov  -0.0054 0.7045 -0.0148 0.0041  False
#   N_back Sem_Pred  -0.0016 0.9999  -0.011 0.0078  False
#   N_back      ToM  -0.0017 0.9999 -0.0111 0.0078  False
#   N_back    Vis_S   0.0017 0.9999 -0.0078 0.0111  False
#     Rest  Rom_mov  -0.0018 0.9998 -0.0112 0.0076  False
#     Rest Sem_Pred   0.0019 0.9996 -0.0075 0.0114  False
#     Rest      ToM   0.0019 0.9997 -0.0075 0.0113  False
#     Rest    Vis_S   0.0052 0.7385 -0.0042 0.0146  False
#  Rom_mov Sem_Pred   0.0037 0.9532 -0.0057 0.0132  False
#  Rom_mov      ToM   0.0037  0.957 -0.0057 0.0131  False
#  Rom_mov    Vis_S    0.007 0.3284 -0.0024 0.0164  False
# Sem_Pred      ToM  -0.0001    1.0 -0.0095 0.0094  False
# Sem_Pred    Vis_S   0.0033 0.9807 -0.0061 0.0127  False
#      ToM    Vis_S   0.0033 0.9785 -0.0061 0.0127  False
# -------------------------------------------------------
#   Condition  T-statistic   P-value  FDR P-value Significance (FDR)
# 0     Instr    -0.704221  0.499110     0.622707    Not Significant
# 1     Vis_S     1.367103  0.204763     0.511909    Not Significant
# 2     F_Seq     0.896984  0.393089     0.622707    Not Significant
# 3       ToM     0.509428  0.622707     0.622707    Not Significant
# 4    N_back     1.189137  0.264812     0.529624    Not Significant
# 5  Sem_Pred     0.583404  0.573949     0.622707    Not Significant
# 6   Act_Obs    -3.825293  0.004057     0.040569        Significant
# 7  Flex_Ext     1.731132  0.117476     0.511909    Not Significant
# 8      Rest    -0.802696  0.442831     0.622707    Not Significant
# 9   Rom_mov    -1.402119  0.194415     0.511909    Not Significant

# %%
# t-tests of residuals using group regression line as reference 

df = pd.read_csv('subjectwise_ROI_correlations.tsv', sep="\t")
group_df = pd.read_csv('group_ROI_correlations.tsv', sep="\t")

all_rois = df['ROIs'].unique()

# Iterate over each ROI pair
for roi_pair in all_rois:
    # Filter data for the current ROI pair
    df_filtered = df[df['ROIs'] == roi_pair]

    residuals = []

# Loop through the unique conditions
    for condition in df_filtered['cond'].unique():
        condition_data = df_filtered[df_filtered['cond'] == condition]
    
        condition_residuals = []
    
    # Extract the GROUP regression line for this ROI and condition
        group_regression_line = group_df[(group_df['ROIs'] == selected_rois[0]) &
                                     (group_df['cond'] == condition)]['regression line'].iloc[0]

    # Extract the slope and intercept from the group regression line
        slope, intercept = map(float, group_regression_line.split(" * x + "))

    # Loop through each subject to calculate residuals based on the group regression line
        for subj_id in condition_data['Subjects'].unique():
            subject_data = condition_data[condition_data['Subjects'] == subj_id]
        
            x = subject_data['x']
            y = subject_data['y']
        
            # Calculate predicted y-values based on the GROUP regression line
            predicted_y = slope * x + intercept
        
            residuals_for_subject = y - predicted_y
        
        # Append subject's residuals to the condition's list
            condition_residuals.append(residuals_for_subject)
    
    # After looping through subjects for this condition, add the residuals for this condition
        residuals.append(np.array(condition_residuals).T)  # Transpose to get subjects as rows

# Format residuals for ANOVA
residuals = np.array(residuals).T  
residuals = residuals.squeeze()
residuals = residuals.T  # shape is (conditions x subjects)

# Perform one-way ANOVA across conditions
F_value, p_value = f_oneway(*residuals)

# Collect t-values and p-values for t-test
t_values = []
p_values = []

for i in range(10):  # Number of conditions
    t_stat, p_val = ttest_1samp(residuals[i, :], 0)
    t_values.append(t_stat)
    p_values.append(p_val)

# Apply FDR correction
reject, p_values_corrected, _, _ = multipletests(p_values, alpha=0.1, method='fdr_bh')

# Store flagged results
flagged_results = []

for i, cond in enumerate(df_filtered['cond'].unique()):
    t_stat, p_val, p_val_corrected = t_values[i], p_values[i], p_values_corrected[i]
    
    # Flag conditions with corrected p-value < 0.05
    flag = "Significant" if reject[i] else "Not Significant"
    
    flagged_results.append([cond, t_stat, p_val, p_val_corrected, flag])

# Convert flagged results to DataFrame
flagged_df = pd.DataFrame(flagged_results, 
                          columns=["Condition", "T-statistic", "P-value", "FDR P-value", "Significance (FDR)"])

print(selected_rois)
print(flagged_df)
# Out:
# ['dentate vs cereb_gray']
#   Condition  T-statistic   P-value  FDR P-value Significance (FDR)
# 0     Instr    -0.834820  0.416917     0.598228    Not Significant
# 1     Vis_S     0.242028  0.812036     0.902263    Not Significant
# 2     F_Seq     2.849331  0.012183     0.121830    Not Significant
# 3       ToM    -0.726727  0.478582     0.598228    Not Significant
# 4    N_back     1.024621  0.321783     0.598228    Not Significant
# 5  Sem_Pred    -0.120309  0.905835     0.905835    Not Significant
# 6   Act_Obs    -1.418661  0.176441     0.598228    Not Significant
# 7  Flex_Ext     0.823426  0.423165     0.598228    Not Significant
# 8      Rest    -0.748125  0.465954     0.598228    Not Significant
# 9   Rom_mov    -0.872115  0.396891     0.598228    Not Significant

# %%
#t-tests on condition residuals

df = pd.read_csv('subjectwise_ROI_correlations.tsv', sep="\t")
group_df = pd.read_csv('group_ROI_correlations.tsv', sep="\t")

df = df[df["dataset"] == "MDTB"]

# Extract all unique ROI pairs
all_rois = df['ROIs'].unique()

# Create a container for flagged results
all_flagged_results = []

# Iterate over each ROI pair
for roi_pair in all_rois:
    # Filter data for the current ROI pair
    df_filtered = df[df['ROIs'] == roi_pair]

    residuals = []

    # Loop through the unique conditions
    for condition in df_filtered['cond'].unique():
        condition_data = df_filtered[df_filtered['cond'] == condition]

        condition_residuals = []

        # Extract the GROUP regression line for this ROI and condition
        group_regression_line = group_df[(group_df['ROIs'] == roi_pair) &
                                         (group_df['cond'] == condition)]['regression line'].iloc[0]

        # Extract the slope and intercept from the group regression line
        slope, intercept = map(float, group_regression_line.split(" * x + "))

        # Loop through each subject to calculate residuals based on the group regression line
        for subj_id in condition_data['Subjects'].unique():
            subject_data = condition_data[condition_data['Subjects'] == subj_id]

            x = subject_data['x']
            y = subject_data['y']

            # Calculate predicted y-values based on the GROUP regression line
            predicted_y = slope * x + intercept

            residuals_for_subject = y - predicted_y

            # Append subject's residuals to the condition's list
            condition_residuals.append(residuals_for_subject)

        # After looping through subjects for this condition, add the residuals for this condition
        residuals.append(np.array(condition_residuals).T)  # Transpose to get subjects as rows

    # Format residuals for t-tests
    residuals = np.array(residuals).T
    residuals = residuals.squeeze()
    residuals = residuals.T  # shape is (conditions x subjects)

    # Collect t-values and p-values for t-test
    t_values = []
    p_values = []

    for i in range(residuals.shape[0]):  # Number of conditions
        t_stat, p_val = ttest_1samp(residuals[i, :], 0)
        t_values.append(t_stat)
        p_values.append(p_val)

    # Apply FDR correction
    reject, p_values_corrected, _, _ = multipletests(p_values, alpha=0.1, method='fdr_bh')

    # Store flagged results
    for i, cond in enumerate(df_filtered['cond'].unique()):
        t_stat, p_val, p_val_corrected = t_values[i], p_values[i], p_values_corrected[i]

        # Flag conditions with corrected p-value < 0.05
        flag = "Significant" if reject[i] else "Not Significant"

        all_flagged_results.append([roi_pair, cond, t_stat, p_val, p_val_corrected, flag, "MDTB"])

# Convert flagged results to DataFrame
flagged_df = pd.DataFrame(all_flagged_results,
                          columns=["ROI Pair", "Condition", "T-statistic", "P-value", 
                                   "FDR P-value", "Significance (FDR)", "dataset"])

flagged_df.to_csv('residual_t-tests.csv', mode='a', index=False)

# %%
# Load the .tsv file
file_path = "residual_t-tests.csv"  # Replace with your actual file path
df = pd.read_csv(file_path, sep=',')

# Assuming the p-values are in a column named 'p_value'
significant_rows = df[df["Significance (FDR)"] == "Significant"]

filtered_rows = significant_rows[
    (significant_rows["ROI Pair"] == "dentate vs cereb_gray") |
    (significant_rows["ROI Pair"] == "cereb_gray vs dentate")
]

# Print significant rows
print(filtered_rows)
# Out:
#                   ROI Pair        Condition  T-statistic       P-value  \
# 6    dentate vs cereb_gray          Act_Obs    -3.015890  8.686988e-03
# 90   cereb_gray vs dentate             Rest    -4.634105  2.757249e-04
# 99   cereb_gray vs dentate              ToM    -2.834624  1.195523e-02
# 101  cereb_gray vs dentate           N_back    -2.658863  1.715607e-02
# 104  cereb_gray vs dentate          Rom_mov    -2.906274  1.030590e-02
# 129  dentate vs cereb_gray         VideoAct    -7.793776  6.693982e-08
# 130  dentate vs cereb_gray       VideoKnots    -3.026147  6.009400e-03
# 138  dentate vs cereb_gray  Interval_Timing     2.590294  1.636132e-02
# 141  dentate vs cereb_gray       Finger_Seq    -3.637394  1.377755e-03
# 143  dentate vs cereb_gray      Verbal2Back     2.729003  1.196354e-02
# 155  cereb_gray vs dentate             NoGo    -3.063129  5.507627e-03
# 158  cereb_gray vs dentate         VideoAct     8.436408  1.703818e-08
# 159  cereb_gray vs dentate       VideoKnots     5.628262  9.956492e-06
# 160  cereb_gray vs dentate   Unpleas_Scenes    -4.106461  4.317361e-04
# 161  cereb_gray vs dentate     Pleas_scenes    -3.738494  1.074471e-03
# 167  cereb_gray vs dentate  Interval_Timing    -2.608396  1.571160e-02
# 169  cereb_gray vs dentate    Finger_Simple     4.533058  1.490589e-04
# 170  cereb_gray vs dentate       Finger_Seq    11.034682  1.156025e-10
# 171  cereb_gray vs dentate      Verbal0Back    -3.418155  2.352647e-03
# 175  cereb_gray vs dentate      Spatial_Nav     6.345051  1.786260e-06
# 178  cereb_gray vs dentate  Verb_generation     6.758147  6.814081e-07
# 179  cereb_gray vs dentate     Word_reading     5.933736  4.756115e-06
#
#       FDR P-value Significance (FDR)    dataset
# 6    8.686988e-02        Significant  Pontine7T
# 90   4.963049e-03        Significant   Language
# 99   7.173137e-02        Significant   Language
# 101  7.720232e-02        Significant   Language
# 104  7.173137e-02        Significant   Language
# 129  1.941255e-06        Significant       MDTB
# 130  5.809086e-02        Significant       MDTB
# 138  9.489566e-02        Significant       MDTB
# 141  1.997745e-02        Significant       MDTB
# 143  8.673565e-02        Significant       MDTB
# 155  1.452011e-02        Significant       MDTB
# 158  2.470536e-07        Significant       MDTB
# 159  4.812305e-05        Significant       MDTB
# 160  1.565043e-03        Significant       MDTB
# 161  3.462183e-03        Significant       MDTB
# 167  3.796971e-02        Significant       MDTB
# 169  6.175296e-04        Significant       MDTB
# 170  3.352473e-09        Significant       MDTB
# 171  6.822677e-03        Significant       MDTB
# 175  1.295038e-05        Significant       MDTB
# 178  6.586945e-06        Significant       MDTB
# 179  2.758546e-05        Significant       MDTB

# %%
#ANOVA and Tukey’s HSD for all ROI pairs with group as reference

df = pd.read_csv('subjectwise_ROI_correlations.tsv', sep="\t")
group_df = pd.read_csv('group_ROI_correlations.tsv', sep="\t")

df = df[df["dataset"] == "MDTB"]

# Extract all unique ROI pairs
all_rois = df['ROIs'].unique()

# Create containers for results
anova_results = []
tukey_results_list = []
flagged_results = []

# Iterate over each ROI pair
for roi_pair in all_rois:
    # Filter data for the current ROI pair
    df_filtered = df[df['ROIs'] == roi_pair]

    # Create an empty list to store residuals for each condition
    residuals = []

    # Loop through conditions
    for condition in df_filtered['cond'].unique():
        condition_data = df_filtered[df_filtered['cond'] == condition]

        # Extract the GROUP regression line for this ROI and condition
        group_regression_line = group_df[(group_df['ROIs'] == roi_pair) &
                                         (group_df['cond'] == condition)]['regression line'].iloc[0]

        # Extract the slope and intercept
        slope, intercept = map(float, group_regression_line.split(" * x + "))

        # Collect residuals
        condition_residuals = []

        # Loop through each subject
        for subj_id in condition_data['Subjects'].unique():
            subject_data = condition_data[condition_data['Subjects'] == subj_id]

            x = subject_data['x']
            y = subject_data['y']

            # Predicted y-values based on the group regression line
            predicted_y = slope * x + intercept
            residuals_for_subject = y - predicted_y

            condition_residuals.append(residuals_for_subject)

        residuals.append(np.array(condition_residuals).T)  # Transpose to get subjects as rows

    # Format residuals for ANOVA
    residuals = np.array(residuals).T  
    residuals = residuals.squeeze()
    residuals = residuals.T  # shape is (conditions x subjects)

    # Perform one-way ANOVA
    F_value, p_value = f_oneway(*residuals)

    # Store ANOVA results
    anova_results.append([roi_pair, F_value, p_value])

    # Tukey’s HSD
    residuals_flat = residuals.flatten()
    conditions_repeated = np.repeat(df_filtered['cond'].unique(), residuals.shape[1])

    tukey_results = pairwise_tukeyhsd(endog=residuals_flat,
                                      groups=conditions_repeated,
                                      alpha=0.05)
    tukey_results_list.append([roi_pair, tukey_results])

    # Collect t-values and p-values for t-tests
    t_values = []
    p_values = []

    for i in range(residuals.shape[0]):  # Number of conditions
        t_stat, p_val = ttest_1samp(residuals[i, :], 0)
        t_values.append(t_stat)
        p_values.append(p_val)

    # Apply FDR correction
    reject, p_values_corrected, _, _ = multipletests(p_values, alpha=0.1, method='fdr_bh')

    # Store flagged results
    for i, cond in enumerate(df_filtered['cond'].unique()):
        flagged_results.append([roi_pair, cond, t_values[i], p_values[i], p_values_corrected[i],
                                "Significant" if reject[i] else "Not Significant"])

# Convert results to DataFrames
anova_df = pd.DataFrame(anova_results, columns=["ROI Pair", "ANOVA F-value", "ANOVA P-value"])
flagged_df = pd.DataFrame(flagged_results, 
                          columns=["ROI Pair", "Condition", "T-statistic", "P-value", 
                                   "FDR P-value", "Significance (FDR)"])

# Print Results
print(anova_df)
#for roi_pair, tukey_result in tukey_results_list:
    #print(f"\nTukey's HSD for {roi_pair}:")
   # print(tukey_result)

#print("\nSignificance Results (FDR):")
#print(flagged_df)
# Out:
#                 ROI Pair  ANOVA F-value  ANOVA P-value
# 0  dentate vs cereb_gray       4.484161   6.886640e-13
# 1  cereb_gray vs dentate      16.250904   5.281504e-58
